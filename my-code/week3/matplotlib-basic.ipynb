# %% [markdown]
# # 0. Basic

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.rcParams['figure.figsize']=(4,4,)
plt.rcParams['font.size']=10

# %%
myarray = np.array([1,2,3])
plt.plot(myarray)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('basic line plot')
plt.show()

# %%
x=np.array([1,2,3])
y=np.array([2,5,3])
plt.scatter(x,y)
plt.xlabel('some x axis')
plt.ylabel('some y axis')
plt.title('basic scatter plot')
plt.show()

# %% [markdown]
# # 1. Matplotlib + Pandas ==> AWesome!
#
# Pandas는 Matplotlib과 연동되어 손쉽게 그림을 생성하는 기능을 제공한다.
#
# ### Histogram(히스토그램)
# 목적 : Showing the distribution of a numerical variable

# %%
# Example data: Drinks data
drink_cols =['country','beer','spirit','wine','liters','continent']
url='data/drinks.csv'
drinks=pd.read_csv(url, header=0, names=drink_cols, na_filter=False)

# %%
drinks.head(5)
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF
# 3      Andorra   245     138   312    12.4        EU
# 4       Angola   217      57    45     5.9        AF

# %%
drinks['beer']
# Out:
# 0        0
# 1       89
# 2       25
# 3      245
# 4      217
#       ...
# 188    333
# 189    111
# 190      6
# 191     32
# 192     64
# Name: beer, Length: 193, dtype: int64

# %%
drinks['beer'].plot(kind='hist',bins=3)
# Out:
# <Axes: ylabel='Frequency'>

# %%
drinks['beer'].plot(kind='hist',bins=20)
plt.xlabel('Beer Servings')
plt.ylabel('Frequency')
plt.title('Histogram of Beer Servings')
# Out:
# Text(0.5, 1.0, 'Histogram of Beer Servings')

# %%
drinks['beer'].plot(kind='density', xlim=(0, 500))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 drinks['beer'].plot(kind='density', xlim=(0, 500))
#
# File c:\Users\peng2\.conda\envs\my_env\lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\peng2\.conda\envs\my_env\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\peng2\.conda\envs\my_env\lib\site-packages\pandas\plotting\_matplotlib\core.py:453, in MPLPlot.generate(self)
#     451 self._compute_plot_data()
#     452 self._setup_subplots()
# --> 453 self._make_plot()
#     454 self._add_table()
#     455 self._make_legend()
#
# File c:\Users\peng2\.conda\envs\my_env\lib\site-packages\pandas\plotting\_matplotlib\hist.py:167, in HistPlot._make_plot(self)
#     163     kwds["weights"] = weights
#     165 y = reformat_hist_y_given_by(y, self.by)
# --> 167 artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#     169 # when by is applied, show title for subplots to know which group it is
#     170 if self.by is not None:
#
# File c:\Users\peng2\.conda\envs\my_env\lib\site-packages\pandas\plotting\_matplotlib\hist.py:248, in KdePlot._plot(cls, ax, y, style, bw_method, ind, column_num, stacking_id, **kwds)
#     236 @classmethod
#     237 def _plot(
#     238     cls,
#    (...)
#     246     **kwds,
#     247 ):
# --> 248     from scipy.stats import gaussian_kde
#     250     y = remove_na_arraylike(y)
#     251     gkde = gaussian_kde(y, bw_method=bw_method)
#
# ModuleNotFoundError: No module named 'scipy'

# %%
drinks.hist(column='beer', by='continent', figsize=(8,16))
# Out:
# array([[<Axes: title={'center': 'AF'}>, <Axes: title={'center': 'AS'}>],
#        [<Axes: title={'center': 'EU'}>, <Axes: title={'center': 'NA'}>],
#        [<Axes: title={'center': 'OC'}>, <Axes: title={'center': 'SA'}>]],
#       dtype=object)

# %%
drinks.hist(column='beer',by='continent', sharex=True)
# Out:
# array([[<Axes: title={'center': 'AF'}>, <Axes: title={'center': 'AS'}>],
#        [<Axes: title={'center': 'EU'}>, <Axes: title={'center': 'NA'}>],
#        [<Axes: title={'center': 'OC'}>, <Axes: title={'center': 'SA'}>]],
#       dtype=object)

# %%
drinks.hist(column='beer', by='continent', sharex=True, sharey=True)
# Out:
# array([[<Axes: title={'center': 'AF'}>, <Axes: title={'center': 'AS'}>],
#        [<Axes: title={'center': 'EU'}>, <Axes: title={'center': 'NA'}>],
#        [<Axes: title={'center': 'OC'}>, <Axes: title={'center': 'SA'}>]],
#       dtype=object)

# %%
drinks.hist(column='beer', by='continent', sharex=True, layout=(2,3))
# Out:
# array([[<Axes: title={'center': 'AF'}>, <Axes: title={'center': 'AS'}>,
#         <Axes: title={'center': 'EU'}>],
#        [<Axes: title={'center': 'NA'}>, <Axes: title={'center': 'OC'}>,
#         <Axes: title={'center': 'SA'}>]], dtype=object)

# %% [markdown]
# ### Scatter plot(산점도)
# 목적 : Showing the relationship between two numerical variables

# %%
drinks.plot(kind='scatter', x='beer', y='wine')
# Out:
# <Axes: xlabel='beer', ylabel='wine'>

# %%
drinks.plot(kind='scatter', x='beer', y='wine', alpha=0.4)
# Out:
# <Axes: xlabel='beer', ylabel='wine'>

# %%
drinks.plot(kind='scatter', x='beer', y='wine', c='spirit', colormap='Blues')
# Out:
# <Axes: xlabel='beer', ylabel='wine'>

# %%
pd.plotting.scatter_matrix(drinks[['beer', 'spirit', 'wine']], figsize=(10,8))
# Out:
# array([[<Axes: xlabel='beer', ylabel='beer'>,
#         <Axes: xlabel='spirit', ylabel='beer'>,
#         <Axes: xlabel='wine', ylabel='beer'>],
#        [<Axes: xlabel='beer', ylabel='spirit'>,
#         <Axes: xlabel='spirit', ylabel='spirit'>,
#         <Axes: xlabel='wine', ylabel='spirit'>],
#        [<Axes: xlabel='beer', ylabel='wine'>,
#         <Axes: xlabel='spirit', ylabel='wine'>,
#         <Axes: xlabel='wine', ylabel='wine'>]], dtype=object)

# %% [markdown]
# ### Bar plot
# 목적 : Showing a numerical comparison across different categories

# %%
drinks['continent'].value_counts()
# Out:
# continent
# AF    53
# EU    45
# AS    44
# NA    23
# OC    16
# SA    12
# Name: count, dtype: int64

# %%
drinks['continent'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %%
# print(type(drinks.groupby('continent')))
drinks.groupby('continent').head()
#Error 
# drinks.groupby('continent').mean()
# Out:
#                country  beer  spirit  wine  liters continent
# 0          Afghanistan     0       0     0     0.0        AS
# 1              Albania    89     132    54     4.9        EU
# 2              Algeria    25       0    14     0.7        AF
# 3              Andorra   245     138   312    12.4        EU
# 4               Angola   217      57    45     5.9        AF
# 5    Antigua & Barbuda   102     128    45     4.9        NA
# 6            Argentina   193      25   221     8.3        SA
# 7              Armenia    21     179    11     3.8        EU
# 8            Australia   261      72   212    10.4        OC
# 9              Austria   279      75   191     9.7        EU
# 10          Azerbaijan    21      46     5     1.3        EU
# 11             Bahamas   122     176    51     6.3        NA
# 12             Bahrain    42      63     7     2.0        AS
# 13          Bangladesh     0       0     0     0.0        AS
# 14            Barbados   143     173    36     6.3        NA
# 17              Belize   263     114     8     6.8        NA
# 18               Benin    34       4    13     1.1        AF
# 19              Bhutan    23       0     0     0.4        AS
# 20             Bolivia   167      41     8     3.8        SA
# 22            Botswana   173      35    35     5.4        AF
# 23              Brazil   245     145    16     7.2        SA
# 24              Brunei    31       2     1     0.6        AS
# 26        Burkina Faso    25       7     7     4.3        AF
# 32              Canada   240     122   100     8.2        NA
# 35               Chile   130     124   172     7.6        SA
# 37            Colombia   159      76     3     4.2        SA
# 40        Cook Islands     0     254    74     5.9        OC
# 59                Fiji    77      35     1     2.0        OC
# 89            Kiribati    21      34     1     1.0        OC
# 106   Marshall Islands     0       0     0     0.0        OC

# %%
drinks.groupby('continent').head().plot(kind='bar')
# Out:
# <Axes: >

# %%
drinks.groupby('continent').head().drop('liters',axis=1).plot(kind='bar')
# Out:
# <Axes: >

# %%
drinks.groupby('continent').head().drop('liters',axis=1).plot(kind='bar',stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Box plot
# 목적 : Showing quartiles and outliers for one or more numerical variables
#
# **Five-number summary:**
#
# - min = minimum value
# - 25% = first quartile (Q1) = median of the lower half of the data
# - 50% = second quartile (Q2) = median of the data
# - 75% = third quartile (Q3) = median of the upper half of the data
# - max = maximum value
#
# (More useful than mean and standard deviation for describing skewed distributions)
#
# **Interquartile Range (IQR)** = Q3 - Q1
#
# **Outliers:**
#
# - below Q1 - 1.5 * IQR
# - above Q3 + 1.5 * IQR

# %%
from Ipython.display import Image
Image(filename='Box_plot.png')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 from Ipython.display import Image
#       2 Image(filename='Box_plot.png')
#
# ModuleNotFoundError: No module named 'Ipython'

# %%
drinks['spirit'].describe()
# Out:
# count    193.000000
# mean      80.994819
# std       88.284312
# min        0.000000
# 25%        4.000000
# 50%       56.000000
# 75%      128.000000
# max      438.000000
# Name: spirit, dtype: float64

# %%
drinks['spirit'].plot(kind='box')
# Out:
# <Axes: >

# %%
drinks.plot(kind='box')
# Out:
# <Axes: >

# %%
drinks.drop('liters',axis=1).plot(kind='box')
# Out:
# <Axes: >

# %%
drinks.boxplot(column='beer', by='continent',figsize=(8,10))
# Out:
# <Axes: title={'center': 'beer'}, xlabel='continent'>

# %%
drinks.boxplot(by='continent', figsize=(8,10))
# Out:
# array([[<Axes: title={'center': 'beer'}, xlabel='[continent]'>,
#         <Axes: title={'center': 'liters'}, xlabel='[continent]'>],
#        [<Axes: title={'center': 'spirit'}, xlabel='[continent]'>,
#         <Axes: title={'center': 'wine'}, xlabel='[continent]'>]],
#       dtype=object)

# %% [markdown]
# # 2. Saving a plot and Changing a style

# %%
# saving a plot to a file
drinks['beer'].plot(kind='hist', bins=20, title='Histogram of Beer Servings')
plt.xlabel('Beer Servings')
plt.ylabel('Frequency')
plt.savefig('beer_histogram_original.png')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')

# %%
drinks['beer'].plot(kind='hist', bins=20, title='Histogram of Beer Servings.')
plt.xlabel('Beer Servings')
plt.ylabel('Frequency')
plt.savefig('beer_histogram_ggplot.png')

# %%
# Other example
plt.style.use('seaborn-v0_8-pastel')
drinks['beer'].plot(kind='hist', bins=20, title='Histogram of Beer Servings')
plt.xlabel('Beer Servings')
plt.ylabel('Frequency')
plt.savefig('beer_histogram_seaborn.png')

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1=np.arange(0.0,5.0,0.1)
t2=np.arange(0.0,5.0,0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1,f(t1),'ro',t2,f(t2),'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2),'r-.')
plt.show()
